# %%
import pandas as pd

# %% [markdown]
# # Fayldan o'qish

# %%
df = pd.read_csv("cinema.csv")

# %% [markdown]
# # Boshidan nazar solish

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %% [markdown]
# # Kino byudjeti eng katta va eng kichigi topish

# %%
df["Budget"].max()
# Out:
# np.float64(48772.9)

# %%
df["Budget"].min()
# Out:
# np.float64(19781.355)

# %% [markdown]
# # Miqdoriyn o'zgarish

# %%
df["Avg_age_actors"].quantile(0.5)
# Out:
# np.float64(39.0)

# %% [markdown]
# # dublikatlarni o'chirish

# %%
df.drop_duplicates(subset="Genre")
# Out:
#     Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 11            22.3494               70.74               0.476  33379.995
#
#     Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0          138.7               7.825                8.095            7.910
# 1          152.4               7.505                7.650            7.440
# 2          134.6               7.485                7.570            7.495
# 11         156.4               6.865                7.035            6.745
#
#     Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0             7.995           7.94         527367          YES      109.60
# ...

# %% [markdown]
# # Commulative yigindini topish

# %%
df["Movie_length"].cumsum()
# Out:
# 0        138.7
# 1        291.1
# 2        425.7
# 3        545.0
# 4        672.7
#         ...
# 501    71258.1
# 502    71408.3
# 503    71572.8
# 504    71735.6
# 505    71889.9
# Name: Movie_length, Length: 506, dtype: float64

# %% [markdown]
# # Janrlardagi kinolar sonini topish

# %%
df["Genre"].value_counts()
# Out:
# Genre
# Thriller    183
# Comedy      155
# Drama        97
# Action       71
# Name: count, dtype: int64

# %% [markdown]
# # Janrlar hissasi foizlar korinishida

# %%
df["Genre"].value_counts(normalize=True)*100
# Out:
# Genre
# Thriller    36.166008
# Comedy      30.632411
# Drama       19.169960
# Action      14.031621
# Name: proportion, dtype: float64

# %% [markdown]
# # Guruhlash

# %%
df.groupby("Genre")["Avg_age_actors"].agg([min,max,sum])
# Out:
# C:\Users\qwert\AppData\Local\Temp\ipykernel_7712\2851901271.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby("Genre")["Avg_age_actors"].agg([min,max,sum])
# C:\Users\qwert\AppData\Local\Temp\ipykernel_7712\2851901271.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby("Genre")["Avg_age_actors"].agg([min,max,sum])
# ...

# %%
df.groupby("Genre")[["Avg_age_actors","Production expense"]].mean()
# Out:
#           Avg_age_actors  Production expense
# Genre
# Action         42.563380           79.025915
# Comedy         38.606452           79.067226
# Drama          38.773196           76.525155
# Thriller       38.573770           75.471148

# %% [markdown]
# # pivot table yordamida guruhlash

# %%
df.pivot_table(values="Time_taken", index="Genre", columns="Avg_age_actors", fill_value=0)
# Out:
# Avg_age_actors      3           20          21       22       23          24  \
# Genre
# Action            0.00  138.780000  189.640000  110.120  185.560  135.680000
# Comedy          151.24  126.660000  145.376000  151.540  166.740  170.200000
# Drama             0.00  184.573333  134.840000  153.424  159.680  196.120000
# Thriller          0.00  158.120000  145.995556  145.720  170.665  148.986667
#
# Avg_age_actors      25          26      27          28  ...          51  \
# Genre                                                   ...
# Action          217.52    0.000000  179.12  153.840000  ...  137.466667
# Comedy          160.38  155.640000  148.14  119.060000  ...  163.400000
# Drama           148.24  173.680000  163.03  133.386667  ...  147.120000
# Thriller        137.44  159.228571  146.44  137.200000  ...  169.500000
#
# Avg_age_actors          52          53          54      55          56  \
# Genre
# ...

# %%
df.pivot_table(values="Movie_length", index="Genre", columns="Avg_age_actors", fill_value=0)
# Out:
# Avg_age_actors     3           20          21          22          23      24  \
# Genre
# Action            0.0  128.900000  168.000000  149.100000  156.400000  136.50
# Comedy          105.8  138.733333  147.620000  132.928571  159.050000  141.88
# Drama             0.0  142.000000  128.600000  136.580000  134.466667  163.45
# Thriller          0.0  119.222222  123.322222  149.480000  133.650000  139.30
#
# Avg_age_actors      25          26       27          28  ...          51  \
# Genre                                                    ...
# Action          110.40    0.000000  142.800  136.500000  ...  137.833333
# Comedy          157.35  151.120000  133.700  144.275000  ...  162.366667
# Drama           148.35  139.000000  164.925  151.366667  ...  169.700000
# Thriller        145.35  118.428571  111.300  151.225000  ...  133.400000
#
# Avg_age_actors      52          53          54          55      56  \
# Genre
# ...

# %% [markdown]
# # indekslash

# %%
df.set_index("Genre")
# Out:
#           Marketing expense  Production expense  Multiplex coverage  \
# Genre
# Thriller            20.1264               59.62               0.462
# Drama               20.5462               69.14               0.531
# Comedy              20.5458               69.14               0.531
# Drama               20.6474               59.36               0.542
# Drama               21.3810               59.36               0.542
# ...                     ...                 ...                 ...
# Action              21.2526               78.86               0.427
# Action              20.9054               78.86               0.427
# Comedy              21.2152               78.86               0.427
# Comedy              22.1918               78.86               0.427
# Comedy              20.9482               78.86               0.427
#
#              Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# Genre
# ...

# %%
df.set_index("Budget")
# Out:
#            Marketing expense  Production expense  Multiplex coverage  \
# Budget
# 36524.125            20.1264               59.62               0.462
# 35668.655            20.5462               69.14               0.531
# 39912.675            20.5458               69.14               0.531
# 38873.890            20.6474               59.36               0.542
# 39701.585            21.3810               59.36               0.542
# ...                      ...                 ...                 ...
# 36624.115            21.2526               78.86               0.427
# 33996.600            20.9054               78.86               0.427
# 38751.680            21.2152               78.86               0.427
# 37740.670            22.1918               78.86               0.427
# 33496.650            20.9482               78.86               0.427
#
#            Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# Budget
# ...

# %% [markdown]
# # indeksni qaytarish

# %%
df.reset_index()
# Out:
#      index  Marketing expense  Production expense  Multiplex coverage  \
# 0        0            20.1264               59.62               0.462
# 1        1            20.5462               69.14               0.531
# 2        2            20.5458               69.14               0.531
# 3        3            20.6474               59.36               0.542
# 4        4            21.3810               59.36               0.542
# ..     ...                ...                 ...                 ...
# 501    501            21.2526               78.86               0.427
# 502    502            20.9054               78.86               0.427
# 503    503            21.2152               78.86               0.427
# 504    504            22.1918               78.86               0.427
# 505    505            20.9482               78.86               0.427
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# ...

# %% [markdown]
# # isin orqali saralash

# %%
df[df["Genre"].isin(["Drama","Comedy"])]
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# 5              20.5970               59.36               0.542  35718.650
# ..                 ...                 ...                 ...        ...
# 499            23.5566               74.38               0.415  30935.795
# 500            24.4876               74.38               0.415  33479.985
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
df[df["Production expense"].isin([70,80])]
# Out:
# Empty DataFrame
# Columns: [Marketing expense, Production expense, Multiplex coverage, Budget, Movie_length, Lead_ Actor_Rating, Lead_Actress_rating, Director_rating, Producer_rating, Critic_rating, Trailer_views, 3D_available, Time_taken, Twitter_hastags, Genre, Avg_age_actors, Num_multiplex, Collection]
# Index: []

# %% [markdown]
# # indexlash va sortlash

# %%
df.set_index("Genre").sort_index()
# Out:
#           Marketing expense  Production expense  Multiplex coverage  \
# Genre
# Action              21.6442               66.72               0.569
# Action              24.5752               72.12               0.480
# Action              20.7476               65.38               0.485
# Action              21.6374               60.78               0.555
# Action              20.5086               62.56               0.516
# ...                     ...                 ...                 ...
# Thriller            23.3520               69.76               0.507
# Thriller            26.8218               69.76               0.507
# Thriller            26.0694               69.76               0.507
# Thriller            22.6116               75.02               0.453
# Thriller            20.1264               59.62               0.462
#
#              Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# Genre
# ...

# %%
df = df.set_index("Avg_age_actors").sort_index()
print(df)
# Out:
#                 Marketing expense  Production expense  Multiplex coverage  \
# Avg_age_actors
# 3                         22.8104               76.18               0.511
# 20                        20.6718               60.90               0.572
# 20                        21.2302               65.38               0.485
# 20                        39.1154               71.28               0.462
# 20                        22.0656               65.26               0.547
# ...                           ...                 ...                 ...
# 60                       323.5440               91.20               0.260
# 60                        20.7742               65.64               0.595
# 60                        20.8594               65.64               0.595
# 60                        20.8406               85.08               0.536
# 60                       224.6600               91.20               0.386
#
#                    Budget  Movie_length  Lead_ Actor_Rating  \
# ...

# %%
df.set_index("Budget").sort_index()
# Out:
#            Marketing expense  Production expense  Multiplex coverage  \
# Budget
# 19781.355           111.1174               91.20               0.282
# 21458.965           290.4440               91.20               0.369
# 22986.590           389.9640               91.20               0.332
# 22986.590           434.3240               91.20               0.341
# 24264.240           421.6980               91.20               0.300
# ...                      ...                 ...                 ...
# 46523.125            50.3804               94.16               0.395
# 46650.890            30.4028               62.94               0.353
# 48350.720            32.2308               62.94               0.353
# 48467.375            30.5386               67.40               0.496
# 48772.900            89.4856               91.20               0.282
#
#            Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# Budget
# ...

# %% [markdown]
# # loc bn ishlash

# %%
df.loc["Action":"Drama"]
# Out:
# Empty DataFrame
# Columns: [Marketing expense, Production expense, Multiplex coverage, Budget, Movie_length, Lead_ Actor_Rating, Lead_Actress_rating, Director_rating, Producer_rating, Critic_rating, Trailer_views, 3D_available, Time_taken, Twitter_hastags, Genre, Avg_age_actors, Num_multiplex, Collection]
# Index: []

# %%
df.loc[30 : 40]
# Out:
#                 Marketing expense  Production expense  Multiplex coverage  \
# Avg_age_actors
# 30                        20.3902               57.76              0.5839
# 30                        22.9864               65.26              0.5470
# 30                        20.8674               66.28              0.5610
# 30                        20.1812               60.94              0.6000
# 30                        37.6250               98.78              0.3760
# ...                           ...                 ...                 ...
# 40                        21.5792               80.66              0.5630
# 40                        33.1330               62.94              0.3530
# 40                        20.3418               59.04              0.5900
# 40                        22.7108               67.14              0.5910
# 40                       934.9220               91.20              0.3070
#
#                    Budget  Movie_length  Lead_ Actor_Rating  \
# ...

# %%
df1 = df.set_index(["Genre"]).sort_index()

# %%
df1.loc["Comedy"]
# Out:
#         Marketing expense  Production expense  Multiplex coverage     Budget  \
# Genre
# Comedy           128.8228               91.20               0.287  36968.525
# Comedy            22.8206               82.84               0.563  32163.450
# Comedy           264.9440               91.20               0.416  32424.535
# Comedy           145.7614               91.20               0.260  35224.255
# Comedy            22.0000               67.18               0.567  38785.010
# ...                   ...                 ...                 ...        ...
# Comedy            21.0744               82.84               0.563  36379.695
# Comedy            21.0604               61.82               0.511  39323.845
# Comedy            21.2302               65.38               0.485  33152.240
# Comedy            20.7096               62.28               0.608  32641.180
# Comedy            25.9832               68.92               0.536  32530.080
#
# ...

# %%
df1.loc[["Comedy","Drama"]]
# Out:
#         Marketing expense  Production expense  Multiplex coverage     Budget  \
# Genre
# Comedy           128.8228               91.20               0.287  36968.525
# Comedy            22.8206               82.84               0.563  32163.450
# Comedy           264.9440               91.20               0.416  32424.535
# Comedy           145.7614               91.20               0.260  35224.255
# Comedy            22.0000               67.18               0.567  38785.010
# ...                   ...                 ...                 ...        ...
# Drama             23.9604               76.18               0.511  34341.010
# Drama             37.6250               98.78               0.376  31313.535
# Drama             39.7686               71.28               0.462  32291.215
# Drama            179.8496               91.20               0.300  30663.600
# Drama             20.8674               66.28               0.561  33968.825
#
# ...

# %%
df2 = df.set_index(["Genre","Producer_rating"])

# %%
df2.sort_index(level=["Genre","Producer_rating"],ascending=[True,False])
# Out:
#                           Marketing expense  Production expense  \
# Genre    Producer_rating
# Action   9.480                     471.9420               91.20
#          9.325                     337.4880               91.20
#          9.300                     356.2360               91.20
#          9.270                     377.3340               91.20
#          9.265                     183.0348               91.20
# ...                                     ...                 ...
# Thriller 5.655                      20.2622               57.44
#          5.420                      20.9638               62.28
#          4.800                      22.1318               58.82
#          4.750                      21.4488               58.38
#          4.705                      21.5900               58.38
#
#                           Multiplex coverage     Budget  Movie_length  \
# Genre    Producer_rating
# Action   9.480                         0.300  27775.000         163.0
# ...

# %%
df3 = df.set_index("Avg_age_actors")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9440\3099642880.py in ?()
# ----> 1 df3 = df.set_index("Avg_age_actors")
#
# c:\Users\qwert\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Avg_age_actors'] are in the columns"

# %%
df3.loc[30:40]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\qwert\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 30
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df3.loc[30:40]
#
# ...
